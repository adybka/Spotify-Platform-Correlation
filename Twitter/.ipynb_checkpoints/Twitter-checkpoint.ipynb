# %% [markdown]
# # Is There a Correlation Between the Descriptive Metrics of Songs Provided by Spotify and Song Popularity on Various Platforms?

# %% [markdown]
# ## 1.0 Overview:
# ***
# ###  1.1 Analyzing Twitter "Engagement" of Songs Against Spotify Metrics
# The application Spotify contains a wide range of songs, intended to fit any user’s music taste and preferred genre. To determine whether the future popularity of these songs can be predicted based on their inherent characteristics, correlations must be investigated between a known set of song metrics and song popularity at various times on several platforms.
#
# Songs from the chosen Spotify dataset (https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks) are described using the following metrics:
#
# Numerical:
#
#     - acousticness (Ranges from 0 to 1)
#     - danceability (Ranges from 0 to 1)
#     - energy (Ranges from 0 to 1)
#     - duration_ms (Integer typically ranging from 200k to 300k)
#     - instrumentalness (Ranges from 0 to 1)
#     - valence (Ranges from 0 to 1)
#     - popularity (Ranges from 0 to 100)
#     - tempo (Float typically ranging from 50 to 150)
#     - liveness (Ranges from 0 to 1)
#     - loudness (Float typically ranging from -60 to 0)
#     - speechiness (Ranges from 0 to 1)
#     - year (Ranges from 1921 to 2020)
#
# Dummy:
#
#     - mode (0 = Minor, 1 = Major)
#     - explicit (0 = No explicit content, 1 = Explicit content)
#
# Categorical:
#
#     - key (All keys on octave encoded as values ranging from 0 to 11, starting on C as 0, C# as 1 and so on…)
#     - artists (List of artists mentioned)
#     - release_date (Date of release mostly in yyyy-mm-dd format, however precision of date may vary)
#     - name (Name of the song)
# ***
#
# What kinds of correlations exist between a song's Twitter "engagement" and its Spotify metrics?<br>What Spotify musical factor was maximized amongst the songs which create the most discussion/"engagement" on Twitter?<br><br>This analysis will measure the engagement of a song on Twitter by the amount of Tweets that song, as well as the total number of likes, quotes, replies, and retweets those tweets get. This analysis will only consider recent songs (from the past 5 year) due limitations of the Twitter API. This analysis will not consider bots or fake accounts on Twitter and the possible skew they can have on data. This analysis will also not consider the bias of songs being referred to differently on Twitter other than by the names given by the Spotify dataset. The results from this analysis can provide insight for artists and content creators into the type of songs they should create. Artists may use the results to better target their goals for their songs and content.

# %% [markdown]
# ## 2.0 Gathering and Preparing the Data
# ***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## 2.1 Spotify

# %%
# Creating a dataframe using the chosen Spotify data
spotify_data = pd.read_csv('data.csv')
spotify_df = pd.DataFrame(spotify_data, columns=["name","artists","year","popularity","acousticness",\
    "danceability","energy","duration_ms","instrumentalness","valence","tempo","liveness","loudness","speechiness"])
spotify_df
# Out:
#                                                      name  \
# 0                                Keep A Song In Your Soul
# 1                                    I Put A Spell On You
# 2                                            Golfing Papa
# 3       True House Music - Xavier Santos & Carlos Gomi...
# 4                                               Xuniverxe
# ...                                                   ...
# 174384                                            The One
# 174385                                      A Little More
# 174386                                           Together
# 174387                                 champagne problems
# 174388                                     Improvisations
#
#                                    artists  year  popularity  acousticness  \
# 0                          ['Mamie Smith']  1920          12      0.991000
# 1                ["Screamin' Jay Hawkins"]  1920           7      0.643000
# 2                          ['Mamie Smith']  1920           4      0.993000
# 3                      ['Oscar Velazquez']  1920          17      0.000173
# 4                                 ['Mixe']  1920           2      0.295000
# ...                                    ...   ...         ...           ...
# 174384  ['DJ Combo', 'Sander-7', 'Tony T']  2020           0      0.009170
# 174385                    ['Alessia Cara']  2021           0      0.795000
# 174386                       ['Roger Fly']  2020           0      0.806000
# 174387                    ['Taylor Swift']  2021          69      0.920000
# 174388                       ['Roger Fly']  2020           0      0.239000
#
#         danceability  energy  duration_ms  instrumentalness  valence    tempo  \
# 0              0.598   0.224       168333          0.000522   0.6340  149.976
# 1              0.852   0.517       150200          0.026400   0.9500   86.889
# 2              0.647   0.186       163827          0.000018   0.6890   97.600
# 3              0.730   0.798       422087          0.801000   0.0422  127.997
# 4              0.704   0.707       165224          0.000246   0.2990  122.076
# ...              ...     ...          ...               ...      ...      ...
# 174384         0.792   0.866       147615          0.000060   0.1860  125.972
# 174385         0.429   0.211       144720          0.000000   0.2280   94.710
# 174386         0.671   0.589       218147          0.920000   0.7140  108.058
# 174387         0.462   0.240       244000          0.000000   0.3200  171.319
# 174388         0.677   0.460       197710          0.891000   0.7470  112.208
#
#         liveness  loudness  speechiness
# 0         0.3790   -12.628       0.0936
# 1         0.0809    -7.261       0.0534
# 2         0.5190   -12.098       0.1740
# 3         0.1280    -7.311       0.0425
# 4         0.4020    -6.036       0.0768
# ...          ...       ...          ...
# 174384    0.1780    -5.089       0.0356
# 174385    0.1960   -11.665       0.0360
# 174386    0.1130   -12.393       0.0282
# 174387    0.1130   -12.077       0.0377
# 174388    0.2150   -12.237       0.0258
#
# [174389 rows x 14 columns]

# %% [markdown]
# ### 2.1.1 Cleaning the Spotify Data

# %%
# Clean the data to remove duplicates where entries have the same song name
spotify_df = spotify_df.drop_duplicates(subset=['name'])

# Limit the dataframe to only include songs in the past 5 years due to Twitter API's query limitations
# Twitter's search API only returns tweets from the past 7 days, so songs from recent years will be used
# This will likely introduce some bias however
spotify_df = spotify_df.loc[spotify_df['year'] >= 2016]

# Remove song names with non-ASCII characters to help during twitter query
spotify_df = spotify_df[spotify_df['name'].map(lambda x: x.isascii())]
spotify_df.reset_index(drop=True, inplace=True)
spotify_df
# Out:
#                                                     name  \
# 0      The September Of My Years - Live At The Sands ...
# 1      It Was A Very Good Year - Live At The Sands Ho...
# 2      The Circle Game - Live at The 2nd Fret, Philad...
# 3      Urge For Going - Live at The 2nd Fret, Philade...
# 4      What's The Story Mr. Blue - Live at The 2nd Fr...
# ...                                                  ...
# 10804                                     Precious' Tale
# 10805                                 So Fine - TC Remix
# 10806                                         Little Boy
# 10807                                           I giorni
# 10808                                     Nuvole bianche
#
#                                         artists  year  popularity  \
# 0                             ['Frank Sinatra']  2018          27
# 1                             ['Frank Sinatra']  2018          26
# 2                             ['Joni Mitchell']  2020          19
# 3                             ['Joni Mitchell']  2020          19
# 4                             ['Joni Mitchell']  2020          19
# ...                                         ...   ...         ...
# 10804                      ['Jazmine Sullivan']  2021          59
# 10805                             ['Sean Paul']  2021           0
# 10806                              ['Ashnikko']  2021          61
# 10807  ['Ludovico Einaudi', 'Johannes Bornlöf']  2021           0
# 10808  ['Ludovico Einaudi', 'Johannes Bornlöf']  2021           0
#
#        acousticness  danceability  energy  duration_ms  instrumentalness  \
# 0          0.887000         0.319  0.2010       187333          0.000000
# 1          0.938000         0.269  0.1290       236800          0.000005
# 2          0.881000         0.644  0.2120       313093          0.000022
# 3          0.955000         0.627  0.1840       295093          0.000162
# 4          0.888000         0.581  0.3310       183440          0.000015
# ...             ...           ...     ...          ...               ...
# 10804      0.715000         0.734  0.3460        43320          0.000000
# 10805      0.000032         0.530  0.9590       292427          0.027300
# 10806      0.105000         0.781  0.4870       172720          0.000000
# 10807      0.976000         0.358  0.1210       381150          0.889000
# 10808      0.995000         0.297  0.0287       349200          0.908000
#
#        valence    tempo  liveness  loudness  speechiness
# 0       0.2390  117.153    0.9040   -17.796       0.0623
# 1       0.1600   82.332    0.6830   -18.168       0.0576
# 2       0.4410  117.072    0.7980   -14.118       0.0347
# 3       0.2990  115.864    0.0986   -15.533       0.0450
# 4       0.6420   88.303    0.1470   -14.087       0.2430
# ...        ...      ...       ...       ...          ...
# 10804   0.9300   88.849    0.3940   -11.722       0.3550
# 10805   0.2620  173.009    0.3550    -5.648       0.1440
# 10806   0.3270  129.941    0.0802    -7.301       0.1670
# 10807   0.1060  131.808    0.1350   -25.111       0.0532
# 10808   0.0678  141.636    0.0995   -30.008       0.0564
#
# [10809 rows x 14 columns]

# %%
# Check the "popularity" distribution
x = spotify_df["popularity"]
x.hist(histtype = 'stepfilled', bins = 100)
print(f"The median popularity is: {spotify_df['popularity'].median()}")
x.describe()
# Out:
# The median popularity is: 13.0
# count    10809.000000
# mean        28.869923
# std         31.654762
# min          0.000000
# 25%          0.000000
# 50%         13.000000
# 75%         66.000000
# max        100.000000
# Name: popularity, dtype: float64

# %%
# A lot of songs with low popularity, most songs have close to 0 popularity
# We will only take the most popular songs to compare against Tweets
# --> Songs with over 50 popularity
# These songs will likely have engagement on Twitter

# Drop unpopular songs
indexNames = spotify_df[spotify_df['popularity'] < 50].index
spotify_df = spotify_df.drop(indexNames)
spotify_df.reset_index(drop=True, inplace=True)

# Check the "popularity" distribution
x = spotify_df["popularity"]
x.hist(histtype = 'stepfilled', bins = 50)
print(f"The median popularity is: {spotify_df['popularity'].median()}")
x.describe()
# Out:
# The median popularity is: 70.0
# count    3774.000000
# mean       70.260466
# std         7.166509
# min        50.000000
# 25%        65.000000
# 50%        70.000000
# 75%        75.000000
# max       100.000000
# Name: popularity, dtype: float64

# %% [markdown]
# ## 2.2 Twitter API

# %% [markdown]
# This analysis uses the Twitter Standard API v2 (https://developer.twitter.com/en/docs/twitter-api/early-access)
# When searching Tweets the API limits searches to the past 7 days for Standard users (https://developer.twitter.com/en/docs/twitter-api/tweets/search/introduction).
# The API also limits the rate of requests to 450 requests per 15 mins for Standard users (https://developer.twitter.com/en/docs/twitter-api/rate-limits).
#
# To collect the Twitter data, the sample of songs will have to be split into 450 row segments so we can make a search request for each song. Every 15 mins we will run queries on another segment of 450 songs until all the data is collected.

# %% [markdown]
# ### 2.2.1 Collecting Twitter Search Data

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in d:\users\nayeeb\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\nayeeb\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\users\nayeeb\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in d:\users\nayeeb\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\users\nayeeb\anaconda3\lib\site-packages (from requests) (3.0.4)

# %%
import requests
import json
import urllib
import time

# %%
# Get Twitter API keys from another file where API keys are defined
# Specifically, in Keys.ipynb there is:
#      BEARER_TOKEN = "My Bearer Token for Twitter API"
# %run ./Keys.ipynb

# %%
# Define our own function to make Twitter API calls for searching tweets

# define search twitter function
def search_twitter(query, tweet_fields, max_results, bearer_token = BEARER_TOKEN):    
    
    headers = {"Authorization": "Bearer {}".format(bearer_token)}

    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}&{}".format(query, tweet_fields, max_results)
    
    response = requests.request("GET", url, headers=headers)

    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
# define function to collect tweets given all the song names from a data set
# and return lists of the total tweets, likes, quotes, replies, and retweets --> the "engagement"
def collect_tweets(song_names):
    
    # The dataframe columns to be created
    total_tweets = []
    likes = []
    quotes = []
    replies = []
    retweets = []
    
    # For every song given, make a search request
    for song_name in song_names:
        num_tweets = 0
        like_count = 0
        quote_count = 0
        reply_count = 0
        retweet_count = 0

        #search term, quotations in the query mean search for EXACT the given string
        query = f'"{song_name}"'
        query = urllib.parse.quote_plus(query)
        #twitter fields to be returned by api call
        tweet_fields = "tweet.fields=public_metrics"
        #return maximum of 100 tweets (Twitter API's limit)
        max_results = "max_results=100"

        #twitter api call
        try:
            json_response = search_twitter(query=query, tweet_fields=tweet_fields, max_results=max_results, bearer_token=BEARER_TOKEN)
            tweets = json_response.get("data")
            #print(json.dumps(tweets, indent=4, sort_keys=True))
            num_tweets = len(tweets)
            for tweet in tweets:
                like_count += int(tweet.get("public_metrics").get("like_count"))
                quote_count += int(tweet.get("public_metrics").get("quote_count"))
                reply_count += int(tweet.get("public_metrics").get("reply_count"))
                retweet_count += int(tweet.get("public_metrics").get("retweet_count"))
            
            # Append to the columns
            total_tweets.append(num_tweets)
            likes.append(like_count)
            quotes.append(quote_count)
            replies.append(reply_count)
            retweets.append(retweet_count)
        except Exception as e:
            print(f"Failed to query {song_name}: {e}")
    
#     print(total_tweets)
#     print(likes)
#     print(quotes)
#     print(replies)
#     print(retweets)
    return total_tweets, likes, quotes, replies, retweets

# %%
# Take a random sample of 2250 since Twitter API cannot handle too many requests
# Twitter API rate limit = 450 requests allowed every 15 mins
# 1 search request per songs
# 450 x 5 = 2250
sample_df = spotify_df.sample(n = 2250)
sample_df.reset_index(drop=True, inplace=True)
# split into 5 dataframes of 450 songs
df_splits = np.array_split(sample_df, 5)

# %%
#### WARNING This code block takes about 1 hour 20 mins --> It is all the data scraping from Twitter

# Collect Twitter Data on each of the 5 dataframes
# Every 15 mins perform another 450 search requests
for df in df_splits:
    song_names = df["name"].tolist()
    # Sleep for 15 mins + 10 extra seconds just incase
    time.sleep(910)
    total_tweets, likes, quotes, replies, retweets = collect_tweets(song_names)
    tweets_df = pd.DataFrame(list(zip(song_names, total_tweets, likes, quotes, replies, retweets)), columns=["Name","Tweets","Likes","Quotes","Replies","Retweets"])
    # Add to csv file so the data isn't lost incase of crash
    with open("TwitterData.csv", 'a') as f:
        tweets_df.to_csv(f, header=f.tell()==0)
        
# Prints songs which couldn't be queried / returned nothing, these songs were dropped
# Out:
# Failed to query All the Way (I Believe In Steve): object of type 'NoneType' has no len()
# Failed to query Flatliner (feat. Dierks Bentley): object of type 'NoneType' has no len()
# Failed to query When You Down (with Polo G feat. Lil Durk): object of type 'NoneType' has no len()
# Failed to query Cravin (feat. G-Eazy): object of type 'NoneType' has no len()
# Failed to query Now I'm Up To My Neck With Offers: object of type 'NoneType' has no len()
# Failed to query Dreams - 2018 Remaster: object of type 'NoneType' has no len()
# Failed to query Tulou Tagaloa: object of type 'NoneType' has no len()
# Failed to query Off White VLONE (Lil Baby & Gunna feat. Lil Durk & NAV): object of type 'NoneType' has no len()
# Failed to query Dive - Recorded At Sound Stage Nashville: object of type 'NoneType' has no len()
# Failed to query Boys Like You - Acoustic: object of type 'NoneType' has no len()
# Failed to query X (feat. Maluma & Ozuna) - Remix: object of type 'NoneType' has no len()
# Failed to query Deep Sleep Recovery Noise: object of type 'NoneType' has no len()
# Failed to query That's Life (feat. Mac Miller & Sia): object of type 'NoneType' has no len()
# Failed to query Lemonade (Feat. Roddy Ricch & Don Toliver) [Remix]: object of type 'NoneType' has no len()
# Failed to query Baby, It's Cold Outside (feat. Meghan Trainor): object of type 'NoneType' has no len()
# Failed to query 528 Hz Anxiety Relief: object of type 'NoneType' has no len()
# Failed to query Free Jamell (with YNW Melly): object of type 'NoneType' has no len()
# Failed to query Surprise Party (feat. Blackbear): object of type 'NoneType' has no len()
# Failed to query Focus Rain: object of type 'NoneType' has no len()
# Failed to query Hard (feat. Tay-K and BlocBoy JB): object of type 'NoneType' has no len()
# Failed to query (Everybody's Waitin' For) The Man With The Bag - Remastered 1996: object of type 'NoneType' has no len()
# Failed to query Cabin Noise Focus: object of type 'NoneType' has no len()
# Failed to query Gurenge (From "Demon Slayer: Kimetsu no Yaiba"): (400, '{"errors":[{"parameters":{"query":["\\"Gurenge (From \\"Demon Slayer: Kimetsu no Yaiba\\")\\""]},"message":"There were errors processing your request: Reference to invalid field \'Slayer\' (at position 23), Reference to invalid operator \'Slayer\'. Operator is not available in current product or product packaging. Please refer to complete available operator list at http://t.co/operators. (at position 23)"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')
# Failed to query Graduation (with Juice WRLD): object of type 'NoneType' has no len()
# Failed to query Follow You to Virgie (OurVinyl Sessions): object of type 'NoneType' has no len()
# Failed to query 2z Don Corleon: object of type 'NoneType' has no len()
# Failed to query P.S Fuck You Cunt (feat. Lil Peep): object of type 'NoneType' has no len()
# Failed to query Bury Me In Dixie: object of type 'NoneType' has no len()
# Failed to query Storm Rain Sounds: object of type 'NoneType' has no len()
# Failed to query Just Might (with PARTYNEXTDOOR): object of type 'NoneType' has no len()
# Failed to query Don't Rush (feat. DaBaby): object of type 'NoneType' has no len()
# Failed to query Nose on the Grindstone (OurVinyl Sessions): object of type 'NoneType' has no len()
# Failed to query Won't Be Late (feat. Drake): object of type 'NoneType' has no len()
# Failed to query My Family - from "The Addams Family": (400, '{"errors":[{"parameters":{"query":["\\"My Family - from \\"The Addams Family\\"\\""]},"message":"There were errors processing your request: Phrases cannot be empty (at position 37)"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')
# Failed to query I Am (Lil Baby & Gunna): object of type 'NoneType' has no len()
# Failed to query You and Me and Christmastime: object of type 'NoneType' has no len()
# Failed to query Empty Room - Cabu Remix: object of type 'NoneType' has no len()
# Failed to query Rain In The Bay: object of type 'NoneType' has no len()
# Failed to query I Don't Wanna Know (feat. Enya & P. Diddy) - 2016 Remaster: object of type 'NoneType' has no len()
# Failed to query Let's Hear It for the Boy - From "Footloose" Original Soundtrack: object of type 'NoneType' has no len()
# Failed to query El Roto - En Vivo: object of type 'NoneType' has no len()
# Failed to query Christmas Time Is Here - Recorded at Sound Emporium Nashville: object of type 'NoneType' has no len()
# Failed to query Softer Rain: object of type 'NoneType' has no len()
# Failed to query Don't Let Me Down (feat. Daya) - Illenium Remix: object of type 'NoneType' has no len()
# Failed to query do re mi (feat. Gucci Mane): object of type 'NoneType' has no len()
# Failed to query Nah Nah Nah (feat. DaBaby & 2 Chainz) - Remix: object of type 'NoneType' has no len()
# Failed to query Tell Me U Luv Me (with Trippie Redd): object of type 'NoneType' has no len()
# Failed to query Fukashigi no Carte - Seishun Buta Yarou wa Bunny Girl Senpai no Yume wo Minai: object of type 'NoneType' has no len()
# Failed to query Same Bitches (feat. G-Eazy & YG): object of type 'NoneType' has no len()
# Failed to query The Voice (Mixed): object of type 'NoneType' has no len()
# Failed to query White Noise - 700 hz: object of type 'NoneType' has no len()
# Failed to query Sleep Well Rain Sound: object of type 'NoneType' has no len()
# Failed to query Better Day (feat. Aloe Blacc): object of type 'NoneType' has no len()
# Failed to query The Chain - Live 1997; 2018 Remaster: object of type 'NoneType' has no len()
# Failed to query Calm Rain Storm & Gentle White Noise: object of type 'NoneType' has no len()
# Failed to query Ladeando (feat. Fuerza Regida): object of type 'NoneType' has no len()
# Failed to query &burn (with Vince Staples): object of type 'NoneType' has no len()
# Failed to query All Thee Above (feat. Kevin Gates): object of type 'NoneType' has no len()
# Failed to query Coffee (feat. Marc E. Bassy): object of type 'NoneType' has no len()
# Failed to query Aero Noise: object of type 'NoneType' has no len()
# Failed to query Thunderstorm In The Cabin: object of type 'NoneType' has no len()
# Failed to query Molly (feat. Sheff G): object of type 'NoneType' has no len()
# Failed to query Don't Cry (feat. XXXTENTACION): object of type 'NoneType' has no len()
# Failed to query Will you be there when I wake up: object of type 'NoneType' has no len()
# Failed to query Good Example (with Andy Grammer): object of type 'NoneType' has no len()
# Failed to query River Rain Fall: object of type 'NoneType' has no len()
# Failed to query White Noise - 145 hz: object of type 'NoneType' has no len()
# Failed to query Downpoar: object of type 'NoneType' has no len()
# Failed to query Try Everything - From "Zootropolis": (400, '{"errors":[{"parameters":{"query":["\\"Try Everything - From \\"Zootropolis\\"\\""]},"message":"There were errors processing your request: Phrases cannot be empty (at position 36)"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')
# Failed to query Big Fan Dulled: object of type 'NoneType' has no len()
# Failed to query Lyric Pieces, Book 5, Op. 54: Nocturne: object of type 'NoneType' has no len()
# Failed to query Just for a Moment - From "High School Musical: The Musical: The Series": (400, '{"errors":[{"parameters":{"query":["\\"Just for a Moment - From \\"High School Musical: The Musical: The Series\\"\\""]},"message":"There were errors processing your request: Reference to invalid field \'Musical\' (at position 40), Reference to invalid field \'Musical\' (at position 53), Reference to invalid operator \'Musical\'. Operator is not available in current product or product packaging. Please refer to complete available operator list at http://t.co/operators. (at position 40), Reference to invalid operator \'Musical\'. Operator is not available in current product or product packaging. Please refer to complete available operator list at http://t.co/operators. (at position 53), Phrases cannot be empty (at position 72)"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')
# Failed to query What's Up Danger (with Black Caviar): object of type 'NoneType' has no len()
# Failed to query Baby Dreams PT 2: object of type 'NoneType' has no len()
# Failed to query Thunderstorm By The Waterfall: object of type 'NoneType' has no len()
# Failed to query All I Want - From "High School Musical: The Musical: The Series": (400, '{"errors":[{"parameters":{"query":["\\"All I Want - From \\"High School Musical: The Musical: The Series\\"\\""]},"message":"There were errors processing your request: Reference to invalid field \'Musical\' (at position 46), Reference to invalid operator \'Musical\'. Operator is not available in current product or product packaging. Please refer to complete available operator list at http://t.co/operators. (at position 33), Reference to invalid operator \'Musical\'. Operator is not available in current product or product packaging. Please refer to complete available operator list at http://t.co/operators. (at position 46), Phrases cannot be empty (at position 65), Reference to invalid field \'Musical\' (at position 33)"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')
# Failed to query The Christmas Song (Shawn Mendes & Camila Cabello): object of type 'NoneType' has no len()
# Failed to query Leave Em Alone (Layton Greene, Lil Baby feat. City Girls, PnB Rock): object of type 'NoneType' has no len()
# Failed to query You Make It Feel Like Christmas (feat. Blake Shelton): object of type 'NoneType' has no len()
# Failed to query Warm Forest Rain: object of type 'NoneType' has no len()
# Failed to query I'm Still Standing - From "Sing" Original Motion Picture Soundtrack: object of type 'NoneType' has no len()
# Failed to query Open Window Thunder Sounds: object of type 'NoneType' has no len()
# Failed to query Here Comes a Thought (feat. Estelle & AJ Michalka): object of type 'NoneType' has no len()
# Failed to query CIVIL WAR - Bonus: object of type 'NoneType' has no len()
# Failed to query Glittery - From The Kacey Musgraves Christmas Show: object of type 'NoneType' has no len()
# Failed to query Outlaw (feat. Luke Combs): object of type 'NoneType' has no len()
# Failed to query No Limit (feat. Young Thug): object of type 'NoneType' has no len()
# Failed to query Sick and Tired (ft. Machine Gun Kelly and Travis Barker): object of type 'NoneType' has no len()
# Failed to query Deadman's Curve (Live): object of type 'NoneType' has no len()
# Failed to query Fire On Fire - From "Watership Down": (400, '{"errors":[{"parameters":{"query":["\\"Fire On Fire - From \\"Watership Down\\"\\""]},"message":"There were errors processing your request: Phrases cannot be empty (at position 37)"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')
# Failed to query Pure Brown Noise - Loopable with no fade: object of type 'NoneType' has no len()
# Failed to query Monsun Rain Fall: object of type 'NoneType' has no len()
# Failed to query Floor Seats (Text Back): object of type 'NoneType' has no len()
# Failed to query Kings of Summer - Single Version: object of type 'NoneType' has no len()
# Failed to query Hey Julie! (feat. Lil Yachty): object of type 'NoneType' has no len()
# Failed to query Wavy (feat. Joe Moses): object of type 'NoneType' has no len()
# Failed to query Kill The Lights (with Nile Rodgers) - Audien Remix: object of type 'NoneType' has no len()
# Failed to query Brown Noise Hall Verb: object of type 'NoneType' has no len()
# Failed to query Shoulda Named It After Me: object of type 'NoneType' has no len()
# Failed to query Don't Tread on Me (feat. Earl Dibbles Jr.): object of type 'NoneType' has no len()
# Failed to query Just About Over You - Radio Edit: object of type 'NoneType' has no len()
# Failed to query Famous (I'm The One) (feat. Yo Gotti & DeJ Loaf): object of type 'NoneType' has no len()
# Failed to query How Far I'll Go - Reprise: object of type 'NoneType' has no len()
# Failed to query Zero - From the Original Motion Picture "Ralph Breaks The Internet": (400, '{"errors":[{"parameters":{"query":["\\"Zero - From the Original Motion Picture \\"Ralph Breaks The Internet\\"\\""]},"message":"There were errors processing your request: Phrases cannot be empty (at position 68)"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')
# Failed to query Purple Lamborghini (with Rick Ross): object of type 'NoneType' has no len()
# Failed to query Rain Sound : Dark Sky: object of type 'NoneType' has no len()
# Failed to query Earthy Rain With Rolling Thunder: object of type 'NoneType' has no len()
# Failed to query Heartless (with Julia Michaels & Morgan Wallen): object of type 'NoneType' has no len()

# %%
# Create a dataframe from the collected data
twitter_df = pd.read_csv('TwitterData.csv')
twitter_df = pd.DataFrame(twitter_df, columns=["Name","Tweets","Likes","Quotes","Replies","Retweets"])
twitter_df

# Some songs were dropped because they couldn't be queried / returned nothing
# --> Fewer rows than original 2250 sample
# Out:
#                                                  Name  Tweets  Likes  Quotes  \
# 0                                           I'm Still     100      7       0
# 1                                       Happiest Year      99     62       1
# 2                              HEARTBREAK ANNIVERSARY     100     12       1
# 3                                     Real Baby Pluto      73     27       3
# 4                       Havin My Way (feat. Lil Durk)      10      1       0
# ...                                               ...     ...    ...     ...
# 2137                                     Start a Riot       8      1       0
# 2138                   Blessings (feat. Jamila Woods)     100    153       1
# 2139                        Good Thing (with Kehlani)     100    131       1
# 2140  Heartless (with Julia Michaels & Morgan Wallen)     100     54       0
# 2141                         Look Alive (feat. Drake)     100    107       5
#
#       Replies  Retweets
# 0           2      6146
# 1          24       619
# 2           7     70961
# 3          10      5669
# 4           2         0
# ...       ...       ...
# 2137        2         0
# 2138       19     11990
# 2139       22       130
# 2140       22      1373
# 2141       28      4270
#
# [2142 rows x 6 columns]

# %% [markdown]
# ## 3.0 Analysis of the Results
# ***

# %%
# Merge the data with the Spotify data of the same song names
merged = spotify_df.merge(twitter_df, left_on=['name'], right_on=['Name'], how="right")
# Drop extra "Name" column
merged = merged.drop(columns=["Name"])
merged
# Out:
#                       name                 artists  year  popularity  \
# 0              Train Wreck        ['James Arthur']  2016          88
# 1               goosebumps        ['Travis Scott']  2016          87
# 2             I Fall Apart         ['Post Malone']  2016          82
# 3     Say You Won't Let Go        ['James Arthur']  2016          86
# 4                  Redbone    ['Childish Gambino']  2016          82
# ...                    ...                     ...   ...         ...
# 2137         Saint Bernard             ['Lincoln']  2020          68
# 2138            Regardless  ['RAYE', 'Rudimental']  2020          76
# 2139                 @ MEH       ['Playboi Carti']  2020          70
# 2140        Rashida's Tale    ['Jazmine Sullivan']  2021          60
# 2141        Precious' Tale    ['Jazmine Sullivan']  2021          59
#
#       acousticness  danceability  energy  duration_ms  instrumentalness  \
# 0           0.7010         0.311   0.485       208827          0.000000
# 1           0.0847         0.841   0.728       243837          0.000000
# 2           0.0689         0.556   0.538       223347          0.000000
# 3           0.6950         0.358   0.557       211467          0.000000
# 4           0.1670         0.743   0.347       326933          0.009510
# ...            ...           ...     ...          ...               ...
# 2137        0.8250         0.695   0.232       103343          0.000000
# 2138        0.0205         0.749   0.820       197573          0.000685
# 2139        0.0136         0.876   0.492       166799          0.000283
# 2140        0.6150         0.659   0.326        60347          0.000000
# 2141        0.7150         0.734   0.346        43320          0.000000
#
#       valence    tempo  liveness  loudness  speechiness  Tweets  Likes  \
# 0       0.225   77.355    0.0726    -5.726       0.0365     100     63
# 1       0.430  130.049    0.1490    -3.370       0.0484     100     36
# 2       0.291  143.950    0.1960    -5.408       0.0382     100     29
# 3       0.494   85.043    0.0902    -7.398       0.0590     100     65
# 4       0.572  160.143    0.1030   -11.174       0.1210     100     42
# ...       ...      ...       ...       ...          ...     ...    ...
# 2137    0.451  100.488    0.5900   -11.010       0.0972     100    310
# 2138    0.534  120.066    0.0775    -6.114       0.0478     100     36
# 2139    0.400  151.044    0.0678    -8.110       0.1530     100     81
# 2140    0.569  116.004    0.1830   -14.251       0.5030     100     86
# 2141    0.930   88.849    0.3940   -11.722       0.3550      10      6
#
#       Quotes  Replies  Retweets
# 0          0       18       515
# 1          1        8    100031
# 2          0        4     18061
# 3          4       12     14755
# 4          3        6     28399
# ...      ...      ...       ...
# 2137       1       20       995
# 2138       1       40        37
# 2139       0       26      6126
# 2140       1       23        72
# 2141       0        1         0
#
# [2142 rows x 19 columns]

# %%
# Calculate the correlation between the Twitter engagement and the Spotify metrics/ spearman
plt.figure(figsize=(16,16))
# Spearman because of outliers
corrmat = merged.corr(method='spearman')
sns.heatmap(corrmat, annot = True, annot_kws={"size": 10})
corrmat
# Out:
#                       year  popularity  acousticness  danceability    energy  \
# year              1.000000    0.483638     -0.011345      0.178982  0.000370
# popularity        0.483638    1.000000      0.039991      0.145532 -0.004382
# acousticness     -0.011345    0.039991      1.000000     -0.130494 -0.490232
# danceability      0.178982    0.145532     -0.130494      1.000000 -0.041214
# energy            0.000370   -0.004382     -0.490232     -0.041214  1.000000
# duration_ms      -0.246729   -0.074839     -0.013705     -0.202323  0.068180
# instrumentalness -0.127969   -0.094081      0.133792     -0.137530 -0.168748
# valence           0.118065    0.056143     -0.088583      0.298139  0.330609
# tempo             0.040156   -0.016762     -0.165307      0.036503  0.145909
# liveness          0.004377   -0.046154     -0.076764     -0.129302  0.134866
# loudness          0.052243    0.091756     -0.406798      0.060081  0.711205
# speechiness       0.071554    0.015659     -0.079097      0.394568  0.035483
# Tweets            0.022876    0.027091      0.000902     -0.022694  0.008336
# Likes            -0.019997    0.008849     -0.020719     -0.026305 -0.006440
# Quotes           -0.019360   -0.020523      0.022906     -0.011963 -0.016520
# Replies           0.003052    0.016424     -0.028893     -0.006977  0.007656
# Retweets          0.028559    0.027031     -0.005517      0.000213  0.005323
#
#                   duration_ms  instrumentalness   valence     tempo  liveness  \
# year                -0.246729         -0.127969  0.118065  0.040156  0.004377
# popularity          -0.074839         -0.094081  0.056143 -0.016762 -0.046154
# acousticness        -0.013705          0.133792 -0.088583 -0.165307 -0.076764
# danceability        -0.202323         -0.137530  0.298139  0.036503 -0.129302
# energy               0.068180         -0.168748  0.330609  0.145909  0.134866
# duration_ms          1.000000          0.021899 -0.135313  0.037422  0.008121
# instrumentalness     0.021899          1.000000 -0.215874 -0.045989 -0.000432
# valence             -0.135313         -0.215874  1.000000  0.046852 -0.029230
# tempo                0.037422         -0.045989  0.046852  1.000000  0.031179
# liveness             0.008121         -0.000432 -0.029230  0.031179  1.000000
# loudness             0.065377         -0.318138  0.321016  0.141301  0.049783
# speechiness         -0.116293         -0.192473  0.109768  0.142379  0.022636
# Tweets               0.018345         -0.012593 -0.026522 -0.011275 -0.013335
# Likes                0.038353         -0.003685 -0.015665 -0.024839 -0.026827
# Quotes               0.012476         -0.021346 -0.014162 -0.016081 -0.003723
# Replies              0.028396         -0.011666 -0.001976 -0.033073 -0.022899
# Retweets             0.015483         -0.038892 -0.022042  0.002787  0.004402
#
#                   loudness  speechiness    Tweets     Likes    Quotes  \
# year              0.052243     0.071554  0.022876 -0.019997 -0.019360
# popularity        0.091756     0.015659  0.027091  0.008849 -0.020523
# acousticness     -0.406798    -0.079097  0.000902 -0.020719  0.022906
# danceability      0.060081     0.394568 -0.022694 -0.026305 -0.011963
# energy            0.711205     0.035483  0.008336 -0.006440 -0.016520
# duration_ms       0.065377    -0.116293  0.018345  0.038353  0.012476
# instrumentalness -0.318138    -0.192473 -0.012593 -0.003685 -0.021346
# valence           0.321016     0.109768 -0.026522 -0.015665 -0.014162
# tempo             0.141301     0.142379 -0.011275 -0.024839 -0.016081
# liveness          0.049783     0.022636 -0.013335 -0.026827 -0.003723
# loudness          1.000000    -0.037308  0.011237 -0.002670 -0.017712
# speechiness      -0.037308     1.000000 -0.008061 -0.007540 -0.001403
# Tweets            0.011237    -0.008061  1.000000  0.464996  0.336196
# Likes            -0.002670    -0.007540  0.464996  1.000000  0.694301
# Quotes           -0.017712    -0.001403  0.336196  0.694301  1.000000
# Replies           0.009912    -0.012086  0.560709  0.855620  0.642069
# Retweets          0.024913     0.009165  0.784358  0.276167  0.190049
#
#                    Replies  Retweets
# year              0.003052  0.028559
# popularity        0.016424  0.027031
# acousticness     -0.028893 -0.005517
# danceability     -0.006977  0.000213
# energy            0.007656  0.005323
# duration_ms       0.028396  0.015483
# instrumentalness -0.011666 -0.038892
# valence          -0.001976 -0.022042
# tempo            -0.033073  0.002787
# liveness         -0.022899  0.004402
# loudness          0.009912  0.024913
# speechiness      -0.012086  0.009165
# Tweets            0.560709  0.784358
# Likes             0.855620  0.276167
# Quotes            0.642069  0.190049
# Replies           1.000000  0.350454
# Retweets          0.350454  1.000000

# %%
# Calculate the correlation between the Twitter engagement and the Spotify metrics / pearson
plt.figure(figsize=(16,16))
corrmat = merged.corr(method='pearson')
sns.heatmap(corrmat, annot = True, annot_kws={"size": 10})
corrmat
# Out:
#                       year  popularity  acousticness  danceability    energy  \
# year              1.000000    0.475520     -0.034304      0.181643  0.015257
# popularity        0.475520    1.000000      0.018788      0.158639  0.003691
# acousticness     -0.034304    0.018788      1.000000     -0.231656 -0.578586
# danceability      0.181643    0.158639     -0.231656      1.000000  0.069020
# energy            0.015257    0.003691     -0.578586      0.069020  1.000000
# duration_ms      -0.226562   -0.081242     -0.031255     -0.151450  0.074242
# instrumentalness -0.130051   -0.126119      0.202896     -0.357103 -0.200570
# valence           0.123694    0.066239     -0.147775      0.371307  0.338842
# tempo             0.045388   -0.009675     -0.177081      0.111925  0.188369
# liveness         -0.022920   -0.050425     -0.072880     -0.184115  0.139833
# loudness          0.079780    0.113375     -0.468074      0.367190  0.619309
# speechiness       0.064832   -0.041478     -0.078992      0.294856 -0.011526
# Tweets            0.028673    0.020001     -0.011524     -0.007115  0.007182
# Likes            -0.016729   -0.006095      0.015458     -0.037574 -0.034308
# Quotes           -0.005873    0.011019      0.003324     -0.001275 -0.024614
# Replies          -0.006596    0.007059     -0.012432      0.002503 -0.002962
# Retweets          0.030012    0.007418      0.024879      0.004115 -0.018808
#
#                   duration_ms  instrumentalness   valence     tempo  liveness  \
# year                -0.226562         -0.130051  0.123694  0.045388 -0.022920
# popularity          -0.081242         -0.126119  0.066239 -0.009675 -0.050425
# acousticness        -0.031255          0.202896 -0.147775 -0.177081 -0.072880
# danceability        -0.151450         -0.357103  0.371307  0.111925 -0.184115
# energy               0.074242         -0.200570  0.338842  0.188369  0.139833
# duration_ms          1.000000         -0.102666 -0.121070  0.056884  0.031273
# instrumentalness    -0.102666          1.000000 -0.238770 -0.174558  0.151226
# valence             -0.121070         -0.238770  1.000000  0.079219 -0.050713
# tempo                0.056884         -0.174558  0.079219  1.000000 -0.012571
# liveness             0.031273          0.151226 -0.050713 -0.012571  1.000000
# loudness             0.104652         -0.559684  0.363716  0.241970 -0.043538
# speechiness         -0.070710         -0.094945  0.079823  0.146120  0.033568
# Tweets               0.013043         -0.019928 -0.012742 -0.002550  0.021345
# Likes               -0.001837          0.030334 -0.036030  0.000726 -0.010988
# Quotes               0.004464          0.026392  0.018662  0.040129  0.004182
# Replies              0.003033         -0.004712  0.012975 -0.026456  0.008054
# Retweets            -0.023077         -0.011612 -0.000151  0.030406 -0.018566
#
#                   loudness  speechiness    Tweets     Likes    Quotes  \
# year              0.079780     0.064832  0.028673 -0.016729 -0.005873
# popularity        0.113375    -0.041478  0.020001 -0.006095  0.011019
# acousticness     -0.468074    -0.078992 -0.011524  0.015458  0.003324
# danceability      0.367190     0.294856 -0.007115 -0.037574 -0.001275
# energy            0.619309    -0.011526  0.007182 -0.034308 -0.024614
# duration_ms       0.104652    -0.070710  0.013043 -0.001837  0.004464
# instrumentalness -0.559684    -0.094945 -0.019928  0.030334  0.026392
# valence           0.363716     0.079823 -0.012742 -0.036030  0.018662
# tempo             0.241970     0.146120 -0.002550  0.000726  0.040129
# liveness         -0.043538     0.033568  0.021345 -0.010988  0.004182
# loudness          1.000000     0.000644  0.008725 -0.040472 -0.025120
# speechiness       0.000644     1.000000  0.001421 -0.004610  0.016084
# Tweets            0.008725     0.001421  1.000000  0.311579  0.181278
# Likes            -0.040472    -0.004610  0.311579  1.000000  0.205699
# Quotes           -0.025120     0.016084  0.181278  0.205699  1.000000
# Replies           0.011634    -0.007948  0.491565  0.554286  0.260958
# Retweets         -0.005443     0.009590  0.090103 -0.039075 -0.018549
#
#                    Replies  Retweets
# year             -0.006596  0.030012
# popularity        0.007059  0.007418
# acousticness     -0.012432  0.024879
# danceability      0.002503  0.004115
# energy           -0.002962 -0.018808
# duration_ms       0.003033 -0.023077
# instrumentalness -0.004712 -0.011612
# valence           0.012975 -0.000151
# tempo            -0.026456  0.030406
# liveness          0.008054 -0.018566
# loudness          0.011634 -0.005443
# speechiness      -0.007948  0.009590
# Tweets            0.491565  0.090103
# Likes             0.554286 -0.039075
# Quotes            0.260958 -0.018549
# Replies           1.000000 -0.039817
# Retweets         -0.039817  1.000000

# %%
from scipy.stats import spearmanr

# Plot the Popularity vs. Twitter metrics of the songs to see if there are any trends
features = ['Tweets', 'Likes', 'Quotes', 'Replies', 'Retweets']
target = merged['popularity']

fig = plt.gcf()

fig.set_size_inches((12,3))

plt.figure(figsize=(22, 5))

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = merged[col]
    y = target
    
    # Scatter plot with Pearson and Spearman correlations labelled
    plt.scatter(x, y, marker='o', s = 2, label=f'Pearson correlation = {np.round(np.corrcoef(x,y)[0,1], 3)}' +\
                '\n' + f'Spearman correlation = {np.round(stats.spearmanr(x,y)[0], 3)}')
    
    # Line of best fit
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    plt.plot(x, p(x), "r--")
    
    plt.title(f"Popularity vs. {col}")
    plt.xlabel(col)
    plt.ylabel('popularity')
    plt.legend()

# %% [markdown]
# ## 4.0 Conclusion
# ***
# In conclusion, there unfortunately does not seem to be significant correlation between the "engagement" of songs on Twitter and any of Spotify's metrics.
#
# The correlation matrix shows that the amount of Tweets, likes, quotes, replies, and retweets songs got in the past 7 days do not correlate to the year, popularity, danceability, etc... described by Spotify.
#
# The scatter plots also show that the Tweets, likes, quotes, replies, and retweets songs got seemed to follow the popularity distribution shown in Section 2.1.1, again showing that there is no significant correlation.
#
# Some significant biases in this analysis include the fact that Twitter API only limits the search to Tweets from the past 7 days. 7 days is very a small window when considering discussions about songs in the past 5 years, which may have affected these results.
