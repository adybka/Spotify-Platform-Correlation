# %% [markdown]
# # Is There a Correlation Between the Descriptive Metrics of Songs Provided by Spotify and Song Popularity on Various Platforms?

# %% [markdown]
# ## 1.0 Overview:
# ***
# ###  1.1 Analyzing Hot 100 Billboard Song Metrics Against Spotify Metrics
# The application Spotify contains a wide range of songs, intended to fit any user’s music taste and preferred genre. To determine whether the future popularity of these songs can be predicted based on their inherent characteristics, correlations must be investigated between a known set of song metrics and song popularity at various times on several platforms.
#
# Songs from the chosen Spotify dataset (https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks) are described using the following metrics:
#
# Numerical:
#
#     - acousticness (Ranges from 0 to 1)
#     - danceability (Ranges from 0 to 1)
#     - energy (Ranges from 0 to 1)
#     - duration_ms (Integer typically ranging from 200k to 300k)
#     - instrumentalness (Ranges from 0 to 1)
#     - valence (Ranges from 0 to 1)
#     - popularity (Ranges from 0 to 100)
#     - tempo (Float typically ranging from 50 to 150)
#     - liveness (Ranges from 0 to 1)
#     - loudness (Float typically ranging from -60 to 0)
#     - speechiness (Ranges from 0 to 1)
#     - year (Ranges from 1921 to 2020)
#
# Dummy:
#
#     - mode (0 = Minor, 1 = Major)
#     - explicit (0 = No explicit content, 1 = Explicit content)
#
# Categorical:
#
#     - key (All keys on octave encoded as values ranging from 0 to 11, starting on C as 0, C# as 1 and so on…)
#     - artists (List of artists mentioned)
#     - release_date (Date of release mostly in yyyy-mm-dd format, however precision of date may vary)
#     - name (Name of the song)
# ***
#
# Questions to answer:<br>
# <br>
# What kinds of correlations exist between a song's Twitter "engagement" and its Spotify metrics?<br>
#
# <br>
# This analysis will use data from the spotify source as well as data found from the following source.
# (https://data.world/kcmillersean/billboard-hot-100-1958-2017) The following metrics were included.
#
# Numerical:
#
#     - Instance (The amount of times a song has made it onto the chart non-concurently)
#     - Previous week position (The position of the song the week before)
#     - Peak positionn (The highest position on the chart that the song has reached as of that week)
#     - Current week on chart (The current position of the song)
#     - Weeks on Chart (The total times the song has appeared on the chart)
#
#
# The source included a file that listed songs that made it onto the top 100 billboard list. These files had a metric that was found to be interesting. It had a count for the amount of weeks a song has been on the top 100 billboard as well as its current position each week, its position on the chart the previous week and its peak position. This analysis can provide useful insight into which spotify metrics play a role in the popularity of a song and how well it might preform on the the weekly billboard top 100 songs according to certain metrics. Artists can use this to see if there are any trends which might influence their song making process.

# %% [markdown]
# ## 2.0 Cleaning and Preparing the Data:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## 2.1 Billboard:

# %%
#Importing data from the file
billboardData = pd.read_csv('Hot Stuff.csv')
billboard = pd.DataFrame(billboardData)
billboard.columns = ['url', 'WeekID', 'Week Position', 'Song', 'Performer', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart']
billboard
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1963-0...    6/1/1963
# 1       http://www.billboard.com/charts/hot-100/1967-0...    1/7/1967
# 2       http://www.billboard.com/charts/hot-100/1971-0...    7/3/1971
# 3       http://www.billboard.com/charts/hot-100/1975-1...  11/29/1975
# 4       http://www.billboard.com/charts/hot-100/1979-0...   9/29/1979
# ...                                                   ...         ...
# 325690  https://www.billboard.com/charts/hot-100/2018-...   3/17/2018
# 325691  https://www.billboard.com/charts/hot-100/2018-...   3/24/2018
# 325692  https://www.billboard.com/charts/hot-100/2018-...   3/31/2018
# 325693  https://www.billboard.com/charts/hot-100/2018-...    4/7/2018
# 325694  https://www.billboard.com/charts/hot-100/2018-...   4/14/2018
#
#         Week Position                          Song         Performer  \
# 0                  11                         Still     Bill Anderson
# 1                  11           Coming Home Soldier      Bobby Vinton
# 2                  11  She's Not Just Another Woman       The 8th Day
# 3                  11                Saturday Night  Bay City Rollers
# 4                  11                     Pop Muzik                 M
# ...               ...                           ...               ...
# 325690             38              You Make It Easy      Jason Aldean
# 325691             34              You Make It Easy      Jason Aldean
# 325692             36              You Make It Easy      Jason Aldean
# 325693             34              You Make It Easy      Jason Aldean
# 325694             36              You Make It Easy      Jason Aldean
#
#                                          SongID  Instance  \
# 0                            StillBill Anderson       1.0
# 1               Coming Home SoldierBobby Vinton       1.0
# 2       She's Not Just Another WomanThe 8th Day       1.0
# 3                Saturday NightBay City Rollers       1.0
# 4                                    Pop MuzikM       1.0
# ...                                         ...       ...
# 325690             You Make It EasyJason Aldean       1.0
# 325691             You Make It EasyJason Aldean       1.0
# 325692             You Make It EasyJason Aldean       1.0
# 325693             You Make It EasyJason Aldean       1.0
# 325694             You Make It EasyJason Aldean       1.0
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 0                         17.0           11.0             8.0
# 1                         17.0           11.0             8.0
# 2                         17.0           11.0             8.0
# 3                         17.0           11.0             8.0
# 4                         17.0           11.0             8.0
# ...                        ...            ...             ...
# 325690                    38.0           28.0             6.0
# 325691                    38.0           28.0             7.0
# 325692                    34.0           28.0             8.0
# 325693                    36.0           28.0             9.0
# 325694                    34.0           28.0            10.0
#
# [325695 rows x 10 columns]

# %%
#dropping all duplicate songs and only keeping the latest one
uniqueSongs = billboard.sort_values('Weeks on Chart').drop_duplicates('SongID', keep='last')
uniqueSongs.dropna(subset=['Weeks on Chart'], inplace=True)
uniqueSongs
# Out:
#                                                       url      WeekID  \
# 25108   http://www.billboard.com/charts/hot-100/1958-0...   8/16/1958
# 25105   https://www.billboard.com/charts/hot-100/2019-...    6/8/2019
# 25104   https://www.billboard.com/charts/hot-100/2019-...   5/11/2019
# 25097   https://www.billboard.com/charts/hot-100/2018-...   7/21/2018
# 25094   http://www.billboard.com/charts/hot-100/2017-0...   4/22/2017
# ...                                                   ...         ...
# 316988  http://www.billboard.com/charts/hot-100/2012-0...   7/21/2012
# 170307  http://www.billboard.com/charts/hot-100/1998-1...  10/10/1998
# 170314  http://www.billboard.com/charts/hot-100/2009-1...  10/10/2009
# 317010  http://www.billboard.com/charts/hot-100/2014-0...   3/22/2014
# 317018  http://www.billboard.com/charts/hot-100/2014-0...   5/10/2014
#
#         Week Position               Song  \
# 25108              97     Ma Ma Ma Marie
# 25105              96                 HP
# 25104              96     Love Me Anyway
# 25097              96              Kream
# 25094              96         Heatstroke
# ...               ...                ...
# 316988             49  Party Rock Anthem
# 170307             45      How Do I Live
# 170314             48          I'm Yours
# 317010             45               Sail
# 317018             49        Radioactive
#
#                                                 Performer  \
# 25108                                        The Gaylords
# 25105                                              Maluma
# 25104                      P!nk Featuring Chris Stapleton
# 25097                           Iggy Azalea Feauring Tyga
# 25094   Calvin Harris Featuring Young Thug, Pharrell W...
# ...                                                   ...
# 316988          LMFAO Featuring Lauren Bennett & GoonRock
# 170307                                        LeAnn Rimes
# 170314                                         Jason Mraz
# 317010                                         AWOLNATION
# 317018                                    Imagine Dragons
#
#                                                    SongID  Instance  \
# 25108                          Ma Ma Ma MarieThe Gaylords       1.0
# 25105                                            HPMaluma       1.0
# 25104        Love Me AnywayP!nk Featuring Chris Stapleton       1.0
# 25097                      KreamIggy Azalea Feauring Tyga       1.0
# 25094   HeatstrokeCalvin Harris Featuring Young Thug, ...       1.0
# ...                                                   ...       ...
# 316988  Party Rock AnthemLMFAO Featuring Lauren Bennet...       2.0
# 170307                           How Do I LiveLeAnn Rimes       1.0
# 170314                                I'm YoursJason Mraz       1.0
# 317010                                     SailAWOLNATION       2.0
# 317018                         RadioactiveImagine Dragons       2.0
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 25108                      NaN           97.0             1.0
# 25105                      NaN           96.0             1.0
# 25104                      NaN           96.0             1.0
# 25097                      NaN           96.0             1.0
# 25094                      NaN           96.0             1.0
# ...                        ...            ...             ...
# 316988                    50.0            1.0            68.0
# 170307                    48.0            2.0            69.0
# 170314                    49.0            6.0            76.0
# 317010                    41.0           17.0            79.0
# 317018                    48.0            3.0            87.0
#
# [28350 rows x 10 columns]

# %% [markdown]
# ## 2.2 Spotify:

# %%
#Importing the spotify data
spotifyData = pd.read_csv('data.csv')
spotify = pd.DataFrame(spotifyData)
spotify.columns = ['acousticness', 'artists', 'danceability', 'duration_ms', 'energy', 'explicit', 'id','instrumentalness', 'key',\
            'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo', 'valence', 'year']
spotify
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# 0            168333   0.224         0  0cS0A1fUEUd1EW3FcF8AEI
# 1            150200   0.517         0  0hbkKFIJm7Z05H8Zl9w30f
# 2            163827   0.186         0  11m7laMUgmOKqI3oYzuhne
# 3            422087   0.798         0  19Lc5SfJJ5O1oaxY0fpwfh
# 4            165224   0.707         1  2hJjbsLCytGsnAHfdsLejp
# ...             ...     ...       ...                     ...
# 174384       147615   0.866         0  46LhBf6TvYjZU2SMvGZAbn
# 174385       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
# 174386       218147   0.589         0  48Qj61hOdYmUCFJbpQ29Ob
# 174387       244000   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP
# 174388       197710   0.460         0  57tgYkWQTNHVFEt6xDKKZj
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.000522    5    0.3790   -12.628     0
# 1               0.026400    5    0.0809    -7.261     0
# 2               0.000018    0    0.5190   -12.098     1
# 3               0.801000    2    0.1280    -7.311     1
# 4               0.000246   10    0.4020    -6.036     0
# ...                  ...  ...       ...       ...   ...
# 174384          0.000060    6    0.1780    -5.089     0
# 174385          0.000000    4    0.1960   -11.665     1
# 174386          0.920000    4    0.1130   -12.393     0
# 174387          0.000000    0    0.1130   -12.077     1
# 174388          0.891000    7    0.2150   -12.237     1
#
#                                                      name  popularity  \
# 0                                Keep A Song In Your Soul          12
# 1                                    I Put A Spell On You           7
# 2                                            Golfing Papa           4
# 3       True House Music - Xavier Santos & Carlos Gomi...          17
# 4                                               Xuniverxe           2
# ...                                                   ...         ...
# 174384                                            The One           0
# 174385                                      A Little More           0
# 174386                                           Together           0
# 174387                                 champagne problems          69
# 174388                                     Improvisations           0
#
#        release_date  speechiness    tempo  valence  year
# 0              1920       0.0936  149.976   0.6340  1920
# 1        1920-01-05       0.0534   86.889   0.9500  1920
# 2              1920       0.1740   97.600   0.6890  1920
# 3        1920-01-01       0.0425  127.997   0.0422  1920
# 4        1920-10-01       0.0768  122.076   0.2990  1920
# ...             ...          ...      ...      ...   ...
# 174384   2020-12-25       0.0356  125.972   0.1860  2020
# 174385   2021-01-22       0.0360   94.710   0.2280  2021
# 174386   2020-12-09       0.0282  108.058   0.7140  2020
# 174387   2021-01-07       0.0377  171.319   0.3200  2021
# 174388   2020-12-09       0.0258  112.208   0.7470  2020
#
# [174389 rows x 19 columns]

# %%
#Graphing the popularity metric of the spotify data
x = spotify["popularity"]
x.hist(histtype = 'stepfilled', bins = 100)
print(f"The median of the popularity metric is: {spotify['popularity'].median()}")
x.describe()
# Out:
# The median of the popularity metric is: 25.0
# count    174389.000000
# mean         25.693381
# std          21.872740
# min           0.000000
# 25%           1.000000
# 50%          25.000000
# 75%          42.000000
# max         100.000000
# Name: popularity, dtype: float64

# %%
#Removing all songs with less then 5 popularity
lowPop = spotify[spotify['popularity'] < 5].index
spotify = spotify.drop(lowPop)
spotify.reset_index(drop=True, inplace=True)

#Cleaned up the cells in the artists columns to allow the uniqueSongs and Spotify songs to merge properly
spotify['artists'] = spotify['artists'].map(lambda x: x.lstrip("['").rstrip("']"))

#Graphing the popularity again
x = spotify["popularity"]
x.hist(histtype = 'stepfilled', bins = 25)
print(f"The median popularity is: {spotify['popularity'].median()}")
x.describe()
# Out:
# The median popularity is: 35.0
# count    123865.000000
# mean         36.007298
# std          17.492904
# min           5.000000
# 25%          23.000000
# 50%          35.000000
# 75%          48.000000
# max         100.000000
# Name: popularity, dtype: float64

# %% [markdown]
# ## 3.0 Analysis of the Data:

# %%
#Merging all songs with matching titles and artist 
merged_df = pd.merge(spotify, uniqueSongs, left_on = ['name','artists'], right_on = ['Song','Performer'])
#Dropped all columns that had no valuable data as it was cluttering the matrix
merged_df = merged_df.drop(columns=['name', 'artists', 'Instance' , 'Week Position', 'Previous Week Position', 'Peak Position'])
merged_df
# Out:
#       acousticness  danceability  duration_ms  energy  explicit  \
# 0           0.4460         0.523       124120   0.373         0
# 1           0.4570         0.479       125093   0.416         0
# 2           0.9740         0.111       156867   0.184         0
# 3           0.9640         0.180       156893   0.137         0
# 4           0.8480         0.400       165360   0.205         0
# ...            ...           ...          ...     ...       ...
# 9824        0.0142         0.746       204150   0.825         0
# 9825        0.1780         0.770       256440   0.775         0
# 9826        0.0169         0.740       207039   0.498         0
# 9827        0.0507         0.652       177391   0.453         0
# 9828        0.8080         0.557       293453   0.496         0
#
#                           id  instrumentalness  key  liveness  loudness  ...  \
# 0     7M4oVTTFtUptZBD6jB9PLf          0.000011    9    0.1030   -12.990  ...
# 1     1k1Bqnv2R0uJXQN4u6LKYt          0.000017    4    0.1180   -11.451  ...
# 2     0nXn0SUs0tltQODYyNbqcc          0.045600    8    0.1110   -15.011  ...
# 3     2JwJqDEqC5IPl5bN3klNHD          0.420000    8    0.1230   -14.959  ...
# 4     5m9I1v9lHr8nmNoqaQXqgX          0.000000    7    0.4000   -11.794  ...
# ...                      ...               ...  ...       ...       ...  ...
# 9824  7ssEhls1ZYEGtBsoovkMSe          0.010700    1    0.1210    -4.666  ...
# 9825  2swZ0X1njeU32SNJeBKIfW          0.000000    8    0.0651    -4.650  ...
# 9826  7LzouaWGFCy4tkXDOOnEyM          0.002820   11    0.3190    -6.684  ...
# 9827  7DHApOHsIFo7EyfieArYGE          0.000000    1    0.1790    -6.119  ...
# 9828  1fzAuUVbzlhZ1lJAx9PtY6          0.000173    0    0.0772    -9.602  ...
#
#       speechiness    tempo valence  year  \
# 0          0.0932   79.855   0.493  1942
# 1          0.1240   79.593   0.514  1971
# 2          0.0344   76.416   0.214  1945
# 3          0.0336   91.049   0.211  1962
# 4          0.0270   79.545   0.357  1947
# ...           ...      ...     ...   ...
# 9824       0.1690  152.914   0.584  2019
# 9825       0.0349  124.013   0.848  2019
# 9826       0.0456   98.016   0.652  2019
# 9827       0.0445   88.039   0.432  2019
# 9828       0.0563  149.983   0.265  2019
#
#                                                     url      WeekID  \
# 0     http://www.billboard.com/charts/hot-100/1971-1...  10/30/1971
# 1     http://www.billboard.com/charts/hot-100/1971-1...  10/30/1971
# 2     http://www.billboard.com/charts/hot-100/1960-1...  12/24/1960
# 3     http://www.billboard.com/charts/hot-100/1960-1...  12/24/1960
# 4     http://www.billboard.com/charts/hot-100/1964-0...   1/25/1964
# ...                                                 ...         ...
# 9824  https://www.billboard.com/charts/hot-100/2018-...    9/8/2018
# 9825  https://www.billboard.com/charts/hot-100/2019-...   4/20/2019
# 9826  https://www.billboard.com/charts/hot-100/2019-...  11/30/2019
# 9827  https://www.billboard.com/charts/hot-100/2019-...   7/27/2019
# 9828  https://www.billboard.com/charts/hot-100/2019-...    9/7/2019
#
#                    Song       Performer                         SongID  \
# 0     Ain't No Sunshine    Bill Withers  Ain't No SunshineBill Withers
# 1     Ain't No Sunshine    Bill Withers  Ain't No SunshineBill Withers
# 2          Silent Night     Bing Crosby        Silent NightBing Crosby
# 3          Silent Night     Bing Crosby        Silent NightBing Crosby
# 4          Pretty Paper     Roy Orbison        Pretty PaperRoy Orbison
# ...                 ...             ...                            ...
# 9824           Level Up           Ciara                  Level UpCiara
# 9825           Inmortal        Aventura               InmortalAventura
# 9826               Liar  Camila Cabello             LiarCamila Cabello
# 9827       Walk Me Home            P!nk               Walk Me HomeP!nk
# 9828           Daylight    Taylor Swift           DaylightTaylor Swift
#
#      Weeks on Chart
# 0              16.0
# 1              16.0
# 2               2.0
# 3               2.0
# 4               7.0
# ...             ...
# 9824            6.0
# 9825            1.0
# 9826           11.0
# 9827           20.0
# 9828            1.0
#
# [9829 rows x 23 columns]

# %%
#Showing the correlation matrix between the different metrics of the merged file
plt.figure(figsize=(22,22))
corrmat = merged_df.corr()
sns.heatmap(corrmat, annot = True, annot_kws={"size": 12})
# Out:
# <AxesSubplot:>

# %%
#Plotting different spotify metrics vs the amount of times the song has made it on the top 100 chart
spotify_metrics = ['popularity','year']

fig = plt.gcf()

fig.set_size_inches((12,3))

plt.figure(figsize=(22, 5))

for i, col in enumerate(spotify_metrics):
    plt.subplot(1, len(spotify_metrics) , i+1)
    x = merged_df[col]
    y = merged_df['Weeks on Chart']
    plt.scatter(x, y, marker='o', s = 3)
    plt.title(f"Weeks on Chart vs. {col}")
    plt.xlabel(col)
    plt.ylabel('Weeks on Chart')
    
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")

# %% [markdown]
# ## 4.0 Conclusion:
# ***
# In conclusion, there were no clear correlation between the amount of times a song has been on the top 100 charts and any of Spotify's metrics<br>
# <br>
# The correlation matrix does show a few correlation between the metrics from the Spotify such as loudness increasing over the years, but no real correlation was found between the metrics from the hot 100 billboard file and the Spotify metrics.<br>
# <br>
# As for the plots, there does not seem to be anything significant between them. It does seem that songs that have made it onto the top 100 chart a lot tend to be popular according to the Spotify metric.<br>
# <br>
# Some bias in the data would be the fact that not all songs that were popular on the billboard top 100 are still popular on spotify at the moment.
